# %% [markdown]
# Question 1:
# Step 1. Import the necessary libraries
# Step 2. Import the dataset from this address.
# Step 3. Assign it to a variable called users

# %%
import pandas as pd
users = pd.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/u.user', delimiter='|')
users.head(20)
# Out:
#     user_id  age gender     occupation zip_code
# 0         1   24      M     technician    85711
# 1         2   53      F          other    94043
# 2         3   23      M         writer    32067
# 3         4   24      M     technician    43537
# 4         5   33      F          other    15213
# 5         6   42      M      executive    98101
# 6         7   57      M  administrator    91344
# 7         8   36      M  administrator    05201
# 8         9   29      M        student    01002
# 9        10   53      M         lawyer    90703
# 10       11   39      F          other    30329
# 11       12   28      F          other    06405
# 12       13   47      M       educator    29206
# 13       14   45      M      scientist    55106
# 14       15   49      F       educator    97301
# 15       16   21      M  entertainment    10309
# 16       17   30      M     programmer    06355
# 17       18   35      F          other    37212
# 18       19   40      M      librarian    02138
# ...

# %% [markdown]
# Step 4. Discover what is the mean age per occupation

# %%
grp_by=users.groupby('occupation')

mean_occupation=grp_by.age.mean()

mean_occupation
# Out:
# occupation
# administrator    38.746835
# artist           31.392857
# doctor           43.571429
# educator         42.010526
# engineer         36.388060
# entertainment    29.222222
# executive        38.718750
# healthcare       41.562500
# homemaker        32.571429
# lawyer           36.750000
# librarian        40.000000
# marketing        37.615385
# none             26.555556
# other            34.523810
# programmer       33.121212
# retired          63.071429
# salesman         35.666667
# scientist        35.548387
# student          22.081633
# technician       33.148148
# writer           36.311111
# Name: age, dtype: float64

# %% [markdown]
# Step 5. Discover the Male ratio per occupation and sort it from the most to the least

# %%
users[users['gender']=='M'].groupby('occupation')['gender'].count().sort_values(ascending=False)
# Out:
# occupation
# student          136
# other             69
# educator          69
# engineer          65
# programmer        60
# administrator     43
# executive         29
# scientist         28
# technician        26
# writer            26
# librarian         22
# marketing         16
# entertainment     16
# artist            15
# retired           13
# lawyer            10
# salesman           9
# doctor             7
# none               5
# healthcare         5
# homemaker          1
# Name: gender, dtype: int64

# %% [markdown]
# Step 6. For each occupation, calculate the minimum and maximum ages

# %%
occu_age_minmax = users.groupby('occupation').agg({'age':['min', 'max']})
print(occu_age_minmax)
# Out:
#               age
#               min max
# occupation
# administrator  21  70
# artist         19  48
# doctor         28  64
# educator       23  63
# engineer       22  70
# entertainment  15  50
# executive      22  69
# healthcare     22  62
# homemaker      20  50
# lawyer         21  53
# librarian      23  69
# marketing      24  55
# none           11  55
# other          13  64
# programmer     20  63
# retired        51  73
# salesman       18  66
# scientist      23  55
# student         7  42
# technician     21  55
# writer         18  60

# %% [markdown]
# Step 7. For each combination of occupation and sex, calculate the mean age

# %%
print("Mean age by occupation and Gender")
users.groupby(['occupation','gender'])['age'].mean()
# Out:
# Mean age by occupation and Gender
# occupation     gender
# administrator  F         40.638889
#                M         37.162791
# artist         F         30.307692
#                M         32.333333
# doctor         M         43.571429
# educator       F         39.115385
#                M         43.101449
# engineer       F         29.500000
#                M         36.600000
# entertainment  F         31.000000
#                M         29.000000
# executive      F         44.000000
#                M         38.172414
# healthcare     F         39.818182
#                M         45.400000
# homemaker      F         34.166667
#                M         23.000000
# lawyer         F         39.500000
#                M         36.200000
# librarian      F         40.000000
#                M         40.000000
# marketing      F         37.200000
#                M         37.875000
# none           F         36.500000
#                M         18.600000
# ...

# %% [markdown]
# Step 8. For each occupation present the percentage of women and men

# %%
gen_occu=users.groupby(['occupation','gender']).agg({'gender':'count'})
occup_count = users.groupby(['occupation']).count()
occup_gender = gen_occu.div(occup_count, level = "occupation")*100
occup_gender.loc[:, 'gender']
# Out:
# occupation     gender
# administrator  F          45.569620
#                M          54.430380
# artist         F          46.428571
#                M          53.571429
# doctor         M         100.000000
# educator       F          27.368421
#                M          72.631579
# engineer       F           2.985075
#                M          97.014925
# entertainment  F          11.111111
#                M          88.888889
# executive      F           9.375000
#                M          90.625000
# healthcare     F          68.750000
#                M          31.250000
# homemaker      F          85.714286
#                M          14.285714
# lawyer         F          16.666667
#                M          83.333333
# librarian      F          56.862745
#                M          43.137255
# marketing      F          38.461538
#                M          61.538462
# none           F          44.444444
#                M          55.555556
# ...

# %% [markdown]
# Question 2:
# Step 1. Import the necessary libraries

# %%
import pandas as panda
#Step 2. Import the dataset from this address
#Step 3. Assign it to a variable called euro12 
euro = panda.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/02_Filtering_%26_Sorting/Euro12/Euro_2012_stats_TEAM.csv')
euro.head()
# Out:
#              Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 0         Croatia      4               13                12             51.9%
# 1  Czech Republic      4               13                18             41.9%
# 2         Denmark      4               10                10             50.0%
# 3         England      5               11                18             50.0%
# 4          France      3               22                24             37.9%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 0            16.0%                          32             0              0
# 1            12.9%                          39             0              0
# 2            20.0%                          27             1              0
# 3            17.2%                          40             0              0
# 4             6.5%                          65             1              0
#
# ...

# %% [markdown]
# Step 4. Select only the Goal column

# %%
euro[['Goals']]
# Out:
#     Goals
# 0       4
# 1       4
# 2       4
# 3       5
# 4       3
# 5      10
# 6       5
# 7       6
# 8       2
# 9       2
# 10      6
# 11      1
# 12      5
# 13     12
# 14      5
# 15      2

# %% [markdown]
# Step 5. How many team participated in the Euro2012?

# %%
euro['Team'].count()
# Out:
# 16

# %% [markdown]
# Step 6. What is the number of columns in the dataset?

# %%
euro.shape[1]
# Out:
# 35

# %% [markdown]
# Step 7. View only the columns Team, Yellow Cards and Red Cards and assign them
# to a dataframe called discipline

# %%
cards = panda.DataFrame(euro, columns=['Team','Yellow Cards', 'Red Cards'])
cards
# Out:
#                    Team  Yellow Cards  Red Cards
# 0               Croatia             9          0
# 1        Czech Republic             7          0
# 2               Denmark             4          0
# 3               England             5          0
# 4                France             6          0
# 5               Germany             4          0
# 6                Greece             9          1
# 7                 Italy            16          0
# 8           Netherlands             5          0
# 9                Poland             7          1
# 10             Portugal            12          0
# 11  Republic of Ireland             6          1
# 12               Russia             6          0
# 13                Spain            11          0
# 14               Sweden             7          0
# 15              Ukraine             5          0

# %% [markdown]
# Step 8. Sort the teams by Red Cards, then to Yellow Cards

# %%
cards.sort_values(by = ['Red Cards','Yellow Cards'], inplace = True)
cards
# Out:
#                    Team  Yellow Cards  Red Cards
# 2               Denmark             4          0
# 5               Germany             4          0
# 3               England             5          0
# 8           Netherlands             5          0
# 15              Ukraine             5          0
# 4                France             6          0
# 12               Russia             6          0
# 1        Czech Republic             7          0
# 14               Sweden             7          0
# 0               Croatia             9          0
# 13                Spain            11          0
# 10             Portugal            12          0
# 7                 Italy            16          0
# 11  Republic of Ireland             6          1
# 9                Poland             7          1
# 6                Greece             9          1

# %% [markdown]
# Step 9. Calculate the mean Yellow Cards given per Team

# %%
euro.groupby('Team')['Yellow Cards'].mean()
# Out:
# Team
# Croatia                 9.0
# Czech Republic          7.0
# Denmark                 4.0
# England                 5.0
# France                  6.0
# Germany                 4.0
# Greece                  9.0
# Italy                  16.0
# Netherlands             5.0
# Poland                  7.0
# Portugal               12.0
# Republic of Ireland     6.0
# Russia                  6.0
# Spain                  11.0
# Sweden                  7.0
# Ukraine                 5.0
# Name: Yellow Cards, dtype: float64

# %% [markdown]
# Step 10. Filter teams that scored more than 6 goalsStep 11. Select the teams that start
# with G

# %%
euro[euro['Goals'] > 6]
# Out:
#        Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5   Germany     10               32                32             47.8%
# 13    Spain     12               42                33             55.9%
#
#    % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5             15.6%                          80             2              1
# 13            16.0%                         100             0              1
#
#     Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                      0  ...          10                 62.6%         63
# 13                     0  ...          15                 93.8%        102
#
#    Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5              49        12             4          0       15        15
# 13             83        19            11          0       17        17
#
#     Players Used
# 5             17
# 13            18
#
# ...

# %% [markdown]
# 11. Select the teams that start with G

# %%
#Step11 Select the teams that startwith G
euro[euro.Team.str.startswith('G')]
# Out:
#       Team  Goals  Shots on target  Shots off target Shooting Accuracy  \
# 5  Germany     10               32                32             47.8%
# 6   Greece      5                8                18             30.7%
#
#   % Goals-to-shots  Total shots (inc. Blocked)  Hit Woodwork  Penalty goals  \
# 5            15.6%                          80             2              1
# 6            19.2%                          32             1              1
#
#    Penalties not scored  ...  Saves made  Saves-to-shots ratio  Fouls Won  \
# 5                     0  ...          10                 62.6%         63
# 6                     1  ...          13                 65.1%         67
#
#   Fouls Conceded  Offsides  Yellow Cards  Red Cards  Subs on  Subs off  \
# 5             49        12             4          0       15        15
# 6             48        12             9          1       12        12
#
#    Players Used
# 5            17
# 6            20
#
# [2 rows x 35 columns]

# %% [markdown]
# Step 12. Select the first 7 columns

# %%
euro.iloc[ : , : 7]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 13. Select all columns except the last 3

# %%
euro.iloc[ : , : -3]
# Out:
#                    Team  Goals  Shots on target  Shots off target  \
# 0               Croatia      4               13                12
# 1        Czech Republic      4               13                18
# 2               Denmark      4               10                10
# 3               England      5               11                18
# 4                France      3               22                24
# 5               Germany     10               32                32
# 6                Greece      5                8                18
# 7                 Italy      6               34                45
# 8           Netherlands      2               12                36
# 9                Poland      2               15                23
# 10             Portugal      6               22                42
# 11  Republic of Ireland      1                7                12
# 12               Russia      5                9                31
# ...

# %% [markdown]
# Step 14. Present only the Shooting Accuracy from England, Italy and Russia

# %%
euro.loc[euro.Team.isin(['England', 'Italy', 'Russia']),['Team','Shooting Accuracy']]
# Out:
#        Team Shooting Accuracy
# 3   England             50.0%
# 7     Italy             43.0%
# 12   Russia             22.5%

# %% [markdown]
# Question 3:

# %%
#Step 1. Import the necessary libraries
import pandas as panda
import random
#Step2 Step 2. Create 3 differents Series, each of length 100, as follows:
#• The first a random number from 1 to 4
first = [[random.randint(1, 4)] for i in range(100)]
df1 = panda.DataFrame(first)
#• The second a random number from 1 to 3
second = [[random.randint(1, 3)] for i in range(100)]
df2 = panda.DataFrame(second)
#• The third a random number from 10,000 to 30,000
third = [[random.randint(10000, 30000)] for i in range(100)]
#Step 3. Create a DataFrame by joinning the Series by column
df3 = panda.DataFrame(third)
df = panda.concat([df1, df2 , df3], axis=1)
df
# Out:
#     0  0      0
# 0   2  1  28961
# 1   4  3  24166
# 2   1  1  26069
# 3   4  2  13485
# 4   3  3  27036
# .. .. ..    ...
# 95  3  3  24131
# 96  1  2  10106
# 97  3  1  28475
# 98  3  1  25525
# 99  3  3  19631
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 4. Change the name of the columns to bedrs, bathrs, price_sqr_meter

# %%
df.columns = ['bedrs', 'bathrs', 'price_sqr_meter']
df
# Out:
#     bedrs  bathrs  price_sqr_meter
# 0       2       1            28961
# 1       4       3            24166
# 2       1       1            26069
# 3       4       2            13485
# 4       3       3            27036
# ..    ...     ...              ...
# 95      3       3            24131
# 96      1       2            10106
# 97      3       1            28475
# 98      3       1            25525
# 99      3       3            19631
#
# [100 rows x 3 columns]

# %% [markdown]
# Step 5. Create a one column DataFrame with the values of the 3 Series and assign it
# to 'bigcolumn'

# %%
df_new = df.bedrs.astype(str).str.cat(df.bathrs.astype(str)).str.cat(df.price_sqr_meter.
astype(str))
df_new.columns = ['bigcolumn']
df_new
# Out:
# 0     2128961
# 1     4324166
# 2     1126069
# 3     4213485
# 4     3327036
#        ...
# 95    3324131
# 96    1210106
# 97    3128475
# 98    3125525
# 99    3319631
# Name: bedrs, Length: 100, dtype: object

# %% [markdown]
# Step 6. Ops it seems it is going only until index 99. Is it true?
# Step 7. Reindex the DataFrame so it goes from 0 to 299

# %%
df_new = df_new.reset_index(drop=True)
df_new.reset_index()
df_new.reindex(index=range(0,299))
# Out:
# 0      2128961
# 1      4324166
# 2      1126069
# 3      4213485
# 4      3327036
#         ...
# 294        NaN
# 295        NaN
# 296        NaN
# 297        NaN
# 298        NaN
# Name: bedrs, Length: 299, dtype: object

# %% [markdown]
# Question 4:

# %%
#Step1 Import the necessary libraries
import pandas as panda
import numpy as nump
#Step2 Import the dataset from the attached file wind.txt
data = panda.read_csv('https://raw.githubusercontent.com/guipsamora/pandas_exercises/master/06_Stats/Wind_Stats/wind.data',sep = '\s+')
data.head()
# Out:
#    Yr  Mo  Dy    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0  61   1   1  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1  61   1   2  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2  61   1   3  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3  61   1   4  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4  61   1   5  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# Step 3. Assign it to a variable called data and replace the first 3 columns by a proper
# datetime index.

# %%
data["Date"] = pd.to_datetime(data[["Yr","Mo","Dy"]].astype(str).agg('-'.join, axis=1))
data = data.drop(columns=["Yr","Mo","Dy"])
#re-arrange cols
data = data[['Date','RPT','VAL','ROS','KIL','SHA','BIR','DUB','CLA','MUL','CLO','BEL','MAL']]
data.head()
# Out:
#         Date    RPT    VAL    ROS    KIL    SHA   BIR    DUB    CLA    MUL  \
# 0 2061-01-01  15.04  14.96  13.17   9.29    NaN  9.87  13.67  10.25  10.83
# 1 2061-01-02  14.71    NaN  10.83   6.50  12.62  7.67  11.50  10.04   9.79
# 2 2061-01-03  18.50  16.88  12.33  10.13  11.17  6.17  11.25    NaN   8.50
# 3 2061-01-04  10.58   6.63  11.75   4.58   4.54  2.88   8.63   1.79   5.83
# 4 2061-01-05  13.33  13.25  11.42   6.17  10.71  8.21  11.92   6.54  10.92
#
#      CLO    BEL    MAL
# 0  12.58  18.50  15.04
# 1   9.67  17.54  13.83
# 2   7.67  12.75  12.71
# 3   5.88   5.46  10.88
# 4  10.34  12.92  11.83

# %% [markdown]
# Step 4. Year 2061? Do we really have data from this year? Create a function to fix it
# and apply it.

# %%
data["Date"] = np.where(pd.DatetimeIndex(data["Date"]).year < 2000,
data.Date,data.Date - pd.offsets.DateOffset(years=100))
data.head()
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [25], in <cell line: 1>()
# ----> 1 data["Date"] = np.where(pd.DatetimeIndex(data["Date"]).year < 2000,
#       2 data.Date,data.Date - pd.offsets.DateOffset(years=100))
#       3 data.head()
#
# NameError: name 'np' is not defined

# %% [markdown]
# Step 5. Set the right dates as the index. Pay attention at the data type, it should be
# datetime64[ns].

# %%
newData = data.set_index("Date")
newData.index.astype("datetime64[ns]")
# Out:
# DatetimeIndex(['2061-01-01', '2061-01-02', '2061-01-03', '2061-01-04',
#                '2061-01-05', '2061-01-06', '2061-01-07', '2061-01-08',
#                '2061-01-09', '2061-01-10',
#                ...
#                '1978-12-22', '1978-12-23', '1978-12-24', '1978-12-25',
#                '1978-12-26', '1978-12-27', '1978-12-28', '1978-12-29',
#                '1978-12-30', '1978-12-31'],
#               dtype='datetime64[ns]', name='Date', length=6574, freq=None)

# %% [markdown]
# Step 6. Compute how many values are missing for each location over the entire
# record.They should be ignored in all calculations below.

# %%
newData.isnull().values.ravel().sum()
# Out:
# 31

# %% [markdown]
# Step 7. Compute how many non-missing values there are in total.

# %%
nD = newData.count()
print("There are total ", nD.sum(), " Non-missing values.")
# Out:
# There are total  78857  Non-missing values.

# %% [markdown]
# Step 8. Calculate the mean windspeeds of the windspeeds over all the locations and
# all the times
# A single number for the entire dataset

# %%
a= newData.mean()
a
# Out:
# RPT    12.362987
# VAL    10.644314
# ROS    11.660526
# KIL     6.306468
# SHA    10.455834
# BIR     7.092254
# DUB     9.797343
# CLA     8.495053
# MUL     8.493590
# CLO     8.707332
# BEL    13.121007
# MAL    15.599079
# dtype: float64

# %% [markdown]
# Step 9. Create a DataFrame called loc_stats and calculate the min, max and mean
# windspeeds and standard deviations of the windspeeds at each location over all the
# days
# A different set of numbers for each location.

# %%
def stats(a):
    a = panda.Series(a)
    Min = a.min()
    Max = a.max()
    Mean = a.mean()
    Std = a.std()
    res = [Min,Max,Mean,Std]
    indx = ["Min","Max","Mean","Std"]
    res = panda.Series(res,index=indx)
    return res
loc_stats = newData.apply(stats)
loc_stats
# Out:
#             RPT        VAL        ROS        KIL        SHA        BIR  \
# Min    0.670000   0.210000   1.500000   0.000000   0.130000   0.000000
# Max   35.800000  33.370000  33.840000  28.460000  37.540000  26.160000
# Mean  12.362987  10.644314  11.660526   6.306468  10.455834   7.092254
# Std    5.618413   5.267356   5.008450   3.605811   4.936125   3.968683
#
#             DUB        CLA        MUL        CLO        BEL        MAL
# Min    0.000000   0.000000   0.000000   0.040000   0.130000   0.670000
# Max   30.370000  31.080000  25.880000  28.210000  42.380000  42.540000
# Mean   9.797343   8.495053   8.493590   8.707332  13.121007  15.599079
# Std    4.977555   4.499449   4.166872   4.503954   5.835037   6.699794

# %% [markdown]
# Step 10. Create a DataFrame called day_stats and calculate the min, max and mean
# windspeed and standard deviations of the windspeeds across all the locations at each
# day.
# A different set of numbers for each day.

# %%
day_stats = newData.apply(stats,axis=1)
day_stats.head()
# Out:
#              Min    Max       Mean       Std
# Date
# 2061-01-01  9.29  18.50  13.018182  2.808875
# 2061-01-02  6.50  17.54  11.336364  3.188994
# 2061-01-03  6.17  18.50  11.641818  3.681912
# 2061-01-04  1.79  11.75   6.619167  3.198126
# 2061-01-05  6.17  13.33  10.630000  2.445356

# %% [markdown]
# Step 11. Find the average windspeed in January for each location.
# Treat January 1961 and January 1962 both as January

# %%
jan_data = newData[newData.index.month == 1]
jan_data.mean()
# Out:
# RPT    14.847325
# VAL    12.914560
# ROS    13.299624
# KIL     7.199498
# SHA    11.667734
# BIR     8.054839
# DUB    11.819355
# CLA     9.512047
# MUL     9.543208
# CLO    10.053566
# BEL    14.550520
# MAL    18.028763
# dtype: float64

# %% [markdown]
# Step 12. Downsample the record to a yearly frequency for each location.

# %%
print( "Yearly frequency:\n", newData.resample('A').mean())
# Out:
# Yearly frequency:
#                    RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1972-12-31  12.463962  10.561311  12.058333  5.929699   9.430410  6.358825
# 1973-12-31  11.828466  10.680493  10.680493  5.547863   9.640877  6.548740
# 1974-12-31  13.643096  11.811781  12.336356  6.427041  11.110986  6.809781
# 1975-12-31  12.008575  10.293836  11.564712  5.269096   9.190082  5.668521
# 1976-12-31  11.737842  10.203115  10.761230  5.109426   8.846339  6.311038
# ...               ...        ...        ...       ...        ...       ...
# 2067-12-31  12.737151  10.990986  11.739397  7.143425  11.630740  7.368164
# 2068-12-31  11.835628  10.468197  11.409754  6.477678  10.760765  6.067322
# 2069-12-31  11.166356   9.723699  10.902000  5.767973   9.873918  6.189973
# 2070-12-31  12.600329  10.726932  11.730247  6.217178  10.567370  7.609452
# 2071-12-31  11.273123   9.095178  11.088329  5.241507   9.440329  6.097151
#
# ...

# %% [markdown]
# Step 13. Downsample the record to a monthly frequency for each location.

# %%
print("Monthly frequency:\n", newData.resample('M').mean())
# Out:
# Monthly frequency:
#                    RPT        VAL        ROS       KIL        SHA       BIR  \
# Date
# 1972-01-31  14.383871  11.848387  13.732258  5.925161  10.823226  7.291290
# 1972-02-29  14.046207  10.814483  12.960000  6.347586  10.918621  7.245172
# 1972-03-31  12.900000  10.505161  13.220323  6.949032  10.996452  6.949677
# 1972-04-30  13.675333  10.638000  13.237667  7.232667  11.253667  7.036333
# 1972-05-31  15.963226  12.636129  14.579355  7.974839  13.021290  7.560968
# ...               ...        ...        ...       ...        ...       ...
# 2071-08-31   9.783226   6.991935  10.227097  4.540968   8.978065  4.797742
# 2071-09-30   8.365000   6.512667   7.704333  3.470667   7.676667  5.462667
# 2071-10-31  12.926129  11.106452  12.467419  5.778065  11.305161  8.562903
# 2071-11-30  13.334667  10.853667  12.223333  6.250667  10.895000  7.660000
# 2071-12-31  13.162581  10.606774  13.367097  6.070000  10.393871  7.841613
#
# ...

# %% [markdown]
# Step 14. Downsample the record to a weekly frequency for each location.

# %%
print("Weekly Frequency:\n", newData.resample('W').mean())
# Out:
# Weekly Frequency:
#                    RPT        VAL        ROS        KIL        SHA        BIR  \
# Date
# 1972-01-02   9.125000   2.545000  13.270000   4.375000   4.980000   2.625000
# 1972-01-09  11.792857   7.761429  11.124286   4.212857   7.742857   5.500000
# 1972-01-16  17.061429  14.494286  16.241429   7.025714  12.231429   8.808571
# 1972-01-23  13.291429  13.375714  10.905714   5.304286  11.874286   8.457143
# 1972-01-30  15.732857  12.928571  16.025714   7.304286  11.665714   6.702857
# ...               ...        ...        ...        ...        ...        ...
# 2071-12-06   9.432857   8.880000   7.755714   2.404286   7.097143   4.291429
# 2071-12-13   9.471429   6.048571   8.330000   3.791429   7.065714   5.614286
# 2071-12-20  21.120000  18.934286  17.741429  10.798571  16.771429  13.542857
# 2071-12-27  12.938571  10.191429  12.685714   5.910000  10.054286   8.178571
# 2072-01-03  13.397500   9.127500  24.280000   7.960000  11.657500   6.872500
#
# ...

# %% [markdown]
# Step 15. Calculate the min, max and mean windspeeds and standard deviations of the
# windspeeds across all locations for each week for the first 52 weeks.

# %%
stats = newData.resample('W').mean().apply(lambda x: [x.count(),x.min(),x.max(),x.mean(),x.std()])
print(stats)
# Out:
#           RPT         VAL         ROS         KIL         SHA         BIR  \
# 0  941.000000  941.000000  941.000000  941.000000  941.000000  941.000000
# 1    3.928571    2.452857    4.687143    1.464286    2.775714    1.310000
# 2   22.647143   23.304286   24.280000   13.930000   22.480000   15.408571
# 3   12.362833   10.640641   11.668382    6.308357   10.454024    7.090037
# 4    3.454099    3.378790    2.862755    2.197214    3.158016    2.559691
#
#           DUB         CLA         MUL         CLO         BEL         MAL
# 0  941.000000  941.000000  941.000000  941.000000  941.000000  941.000000
# 1    2.481429    2.284286    2.445714    1.477143    3.661429    5.088571
# 2   20.308571   17.861429   17.460000   18.150000   26.552857   30.374286
# 3    9.801759    8.492537    8.495299    8.706078   13.116573   15.595794
# 4    3.331341    2.861440    2.652529    2.932325    3.777357    4.485366

# %% [markdown]
# Question 5:

# %%
#Step 1. Import the necessary libraries
import pandas as panda
import numpy as nump
#Step 2. Import the dataset from this address.
#Step 3. Assign it to a variable called chipo. 
chip = panda.read_csv('https://raw.githubusercontent.com/justmarkham/DAT8/master/data/chipotle.tsv', sep = '\t')
#Step4 See the first 10 entries
chip.head(15)
# Out:
#     order_id  quantity                              item_name  \
# 0          1         1           Chips and Fresh Tomato Salsa
# 1          1         1                                   Izze
# 2          1         1                       Nantucket Nectar
# 3          1         1  Chips and Tomatillo-Green Chili Salsa
# 4          2         2                           Chicken Bowl
# 5          3         1                           Chicken Bowl
# 6          3         1                          Side of Chips
# 7          4         1                          Steak Burrito
# 8          4         1                       Steak Soft Tacos
# 9          5         1                          Steak Burrito
# 10         5         1                    Chips and Guacamole
# 11         6         1                   Chicken Crispy Tacos
# 12         6         1                     Chicken Soft Tacos
# 13         7         1                           Chicken Bowl
# ...

# %%
#Step5 What is the number of observations in the dataset? 
chip.shape[0]
# Out:
# 4622

# %%
chip.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4622 entries, 0 to 4621
# Data columns (total 5 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   order_id            4622 non-null   int64
#  1   quantity            4622 non-null   int64
#  2   item_name           4622 non-null   object
#  3   choice_description  3376 non-null   object
#  4   item_price          4622 non-null   object
# dtypes: int64(2), object(3)
# memory usage: 180.7+ KB

# %%
#Step6 What is the number of columns in the dataset?
chip.shape[1]
# Out:
# 5

# %%
#Step7 Print the name of all the columns.
chip.columns
# Out:
# Index(['order_id', 'quantity', 'item_name', 'choice_description',
#        'item_price'],
#       dtype='object')

# %%
#Step8 How is the dataset indexed?
chip.index
# Out:
# RangeIndex(start=0, stop=4622, step=1)

# %%
#Step 9. Which was the most-ordered item?
#Step 10. For the most-ordered item, how many items were ordered?

most_ordered_item = chip.groupby('item_name')['quantity'].max().sort_values(ascending = False)
most_ordered_item[:5]
# Out:
# item_name
# Chips and Fresh Tomato Salsa    15
# Bottled Water                   10
# Side of Chips                    8
# Chips and Guacamole              4
# Chicken Burrito                  4
# Name: quantity, dtype: int64

# %%
#Step 11 What was the most ordered item in the choice_description column?
chip.groupby('choice_description').max()
# Out:
#                                                     order_id  quantity  \
# choice_description
# [Adobo-Marinated and Grilled Chicken, Pinto Bea...       214         1
# [Adobo-Marinated and Grilled Chicken, [Sour Cre...       279         1
# [Adobo-Marinated and Grilled Chicken]                    217         1
# [Adobo-Marinated and Grilled Steak, [Sour Cream...       279         1
# [Adobo-Marinated and Grilled Steak]                      217         1
# ...                                                      ...       ...
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...      1309         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...      1215         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...        51         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...        51         1
# [[Tomatillo-Red Chili Salsa (Hot), Tomatillo-Gr...      1299         1
#
#                                                           item_name item_price
# ...

# %%
#Step 12 How many items were orderd in total?
print("Number of Items = ",chip['quantity'].sum())
# Out:
# Number of Items =  4972

# %%
#Step13
chip.item_price.dtype
# Out:
# dtype('O')

# %%
#Step14
print(chip["item_price"].sum())
# Out:
# $2.39 $3.39 $3.39 $2.39 $16.98 $10.98 $1.69 $11.75 $9.25 $9.25 $4.45 $8.75 $8.75 $11.25 $4.45 $2.39 $8.49 $8.49 $2.18 $8.75 $4.45 $8.99 $3.39 $10.98 $3.39 $2.39 $8.49 $8.99 $1.09 $8.49 $2.39 $8.99 $1.69 $8.99 $1.09 $8.75 $8.75 $4.45 $2.95 $11.75 $2.15 $4.45 $11.25 $11.75 $8.75 $10.98 $8.99 $3.39 $8.99 $3.99 $8.99 $2.18 $10.98 $1.09 $8.99 $2.39 $9.25 $11.25 $11.75 $2.15 $4.45 $9.25 $11.25 $8.75 $8.99 $8.99 $3.39 $8.99 $10.98 $8.99 $1.69 $8.99 $3.99 $8.75 $4.45 $8.75 $8.75 $2.15 $8.75 $11.25 $2.15 $9.25 $8.75 $8.75 $9.25 $8.49 $8.99 $1.09 $9.25 $2.95 $11.75 $11.75 $9.25 $11.75 $4.45 $9.25 $4.45 $11.75 $8.75 $8.75 $4.45 $8.99 $8.99 $3.99 $8.49 $3.39 $8.99 $1.09 $9.25 $4.45 $8.75 $2.95 $4.45 $2.39 $8.49 $8.99 $8.49 $1.09 $8.99 $3.99 $8.75 $9.25 $4.45 $11.25 $4.45 $8.99 $1.09 $9.25 $2.95 $4.45 $11.75 $4.45 $8.49 $2.39 $10.98 $22.50 $11.75 $4.45 $11.25 $4.45 $11.25 $4.45 $11.25 $11.25 $11.75 $9.25 $4.45 $11.48 $17.98 $1.69 $17.50 $4.45 $8.49 $2.39 $17.50 $4.45 $4.45 $11.25 $11.75 $10.98 $8
# ...

# %%
#Step 15
print(len(chip.order_id.unique()))
# Out:
# 1834

# %%
#Step17
chip.item_name.value_counts().count()
# Out:
# 50

# %% [markdown]
# Question 6

# %%
import pandas as panda
import matplotlib.pyplot as pplt
data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
data.plot(x = 'Year', y = ['Marriages_per_1000','Divorces_per_1000'],
label = ['Marraiges' , 'Divorces'])
pplt.title('Marraiges & Divorces Per Capita', color = 'Yellow', fontsize = 20)
pplt.xlabel('Year', color = 'Blue', fontsize = 20)
pplt.ylabel('Per Capita', color = 'Red', fontsize = 20)
pplt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [50], in <cell line: 3>()
#       1 import pandas as panda
#       2 import matplotlib.pyplot as pplt
# ----> 3 data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
#       4 data.plot(x = 'Year', y = ['Marriages_per_1000','Divorces_per_1000'],
#       5 label = ['Marraiges' , 'Divorces'])
#       6 pplt.title('Marraiges & Divorces Per Capita', color = 'Yellow', fontsize = 20)
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# Question 7

# %%
import pandas as pd
import matplotlib.pyplot as plt
# %matplotlib inline
data = pd.read_csv('us-marriages-divorces-1867-2014.csv')
x=pd.DataFrame(data.loc[(data['Year'] == 1900)])
y=pd.DataFrame(data.loc[(data['Year'] == 1950)])
z=pd.DataFrame(data.loc[(data['Year'] == 2000)])
final = pd.concat([x, y, z])
plt.rcParams["figure.figsize"] = (9, 9)
final.plot(x="Year", y=["Marriages_per_1000", "Divorces_per_1000"], kind="bar")
plt.xlabel('Year')
plt.ylabel('Per Capita')
plt.title('Comparison of Marriages and Divorces per capita in the U.S. between 1900, 1950, and 2000')
plt.show()

# %% [markdown]
# Question 8

# %%
newData.plot.barh(x='Actor', y='Count', color = '#FF0000')
pplt.title('Actors Kill Count', fontsize=20, color = 'Black')
pplt.xlabel('Count of kills', color = 'Blue', fontsize = 15)
pplt.ylabel('Actor', color = 'Black', fontsize = 20)

# %% [markdown]
# Question 9

# %%
data = panda.read_csv('roman-emperor-reigns.csv')
import matplotlib.pyplot as pplt
import seaborn as sb
# %matplotlib inline
sb.set()
newdata = data.groupby("Cause_of_Death")['Emperor'].count()
newdata.plot.pie(autopct="%.1f%%", figsize = (7,7) , fontsize = 15, ylabel = '', explode=[0.01]*8)
pplt.title("Roman Emperor's Cause of Death", color = 'Blue', fontsize = 20, fontweight ='bold')
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [51], in <cell line: 1>()
# ----> 1 data = panda.read_csv('roman-emperor-reigns.csv')
#       2 import matplotlib.pyplot as pplt
#       3 import seaborn as sb
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...

# %% [markdown]
# Question 10

# %%
data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
arcade_revenue = data['Total Arcade Revenue (billions)'].values
cs_doctorates_awarded = data[
    'Computer Science Doctorates Awarded (US)'].values

plt.scatter(x=arcade_revenue,y=cs_doctorates_awarded)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Input In [52], in <cell line: 1>()
# ----> 1 data = pd.read_csv('arcade-revenue-vs-cs-doctorates.csv')
#       2 arcade_revenue = data['Total Arcade Revenue (billions)'].values
#       3 cs_doctorates_awarded = data[
#       4     'Computer Science Doctorates Awarded (US)'].values
#
# File ~\anaconda3\lib\site-packages\pandas\util\_decorators.py:311, in deprecate_nonkeyword_arguments.<locals>.decorate.<locals>.wrapper(*args, **kwargs)
#     305 if len(args) > num_allow_args:
#     306     warnings.warn(
#     307         msg.format(arguments=arguments),
#     308         FutureWarning,
#     309         stacklevel=stacklevel,
#     310     )
# --> 311 return func(*args, **kwargs)
#
# ...
